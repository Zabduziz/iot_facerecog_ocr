# %%
from ultralytics import YOLO

model = YOLO("best.pt")
results = model("./TestKamera/zaidan1.jpeg", conf=0.4)

results[0].show()
# Out:
# image 1/1 /home/zaidan/projects/playground/yolow/TestKamera/zaidan1.jpeg: 640x512 1 kepala_pengendara, 1 plat_kendaraan, 62.4ms
# Speed: 2.4ms preprocess, 62.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
# <PIL.Image.Image image mode=RGB size=963x1280>
